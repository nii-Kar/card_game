# %%
#card game project
# play object 
import random
# index 
# game logic draw card
from random import shuffle

def draw_card(order_in_deck,card_in_hand,card_location_used):
    card_in_hand.append(order_in_deck[len(card_location_used)])
    card_location_used.append(order_in_deck[len(card_location_used)])
    return card_in_hand

# print(card_in_hand,order_in_deck)
# number_card_in_hand=0
def start_draw_card_untill_have_5_card_in_hand(number_card_in_hand,order_in_deck,card_in_hand,card_location_used):
    while number_card_in_hand <3 : 
        draw_card(order_in_deck,card_in_hand,card_location_used)
        number_card_in_hand+=1

# put card infor to object
class monster_card_default():
  def __init__(self,monster_name,monster_atk,monster_def,star,monster_type,element):
    self.monster_name=monster_name
    self.monster_atk=monster_atk
    self.monster_def=monster_def
    self.star=star
    self.monster_type=monster_type
    self.element=element
  
# put player infor to object
class player_dualist():
  def __init__(self,dualist_name,dualist_lp,dualist_deck,dualist_hand=[],dualist_field=[]):
    self.dualist_name= dualist_name
    self.dualist_lp= dualist_lp
    self.dualist_deck = dualist_deck
    self.dualist_hand = dualist_hand
    self.dualist_field = dualist_field
  def __str__(self):
    return f' DUALIST =={self.dualist_name}===={self.dualist_lp}LP=='

# put card name in card hand index
def dualist_card_name_in_hand(player_card_name_in_hand,player_card_in_hand,all_monster_card):
  for number in player_card_in_hand :
    player_card_name_in_hand.append(all_monster_card[number].monster_name)
  return player_card_name_in_hand

class card_current_location():
  def __init__(self,dualist_name,card_in_hand,card_in_deck,card_in_graveyard):
    self.dualist_name=dualist_name
    self.card_in_hand=card_in_hand
    self.card_in_deck=card_in_deck
    self.card_in_graveyard=card_in_graveyard

# class draw_card():
#   def __init__(self):
#   # add-hand and del-deck 
#   # order_card_in_deck
#     self.card_in_hand=[]
#     self.card_in_hand.append(order_in_deck[0])
#     order_in_deck.remove[order_in_deck[0]]
#     print(self.card_in_hand)
#     print(order_in_deck)


# GAME LOGIC
# monster batttle like yugiho atk def more power will win and differnt will damege player
# if lose cand will send to graveyard
# monster will power up if it element and type match the condition

# player1_dualist_data=player_dualist('yugi',8000,dualist_deck)
# player2_dualist_data=player_dualist('kaiba',8000,dualist_deck)

# game logic battle element
def battle_phase(frist_atk_monster_card,second_atk_monster_card,dualist1_hp,dualist2_hp):
    if frist_atk_monster_card>second_atk_monster_card:
        dualist1_hp=dualist1_hp-(frist_atk_monster_card-second_atk_monster_card)
        print(f"monster destroy take {frist_atk_monster_card-second_atk_monster_card}")
    
    elif frist_atk_monster_card<second_atk_monster_card:
        dualist2_hp=dualist2_hp-(second_atk_monster_card-frist_atk_monster_card)
        print(f"monster destroy take {second_atk_monster_card-frist_atk_monster_card}")
    
    elif frist_atk_monster_card==second_atk_monster_card:
        print('draw')
    else :
        print('error')



all_monster_card={
                  1:monster_card_default('1:Blue-eye white dragon',3000,2500,8,'Dragon','Light'),
                  2:monster_card_default('2:Black magician',900,1400,3,'Spellcaster','Dark'),
                  3:monster_card_default('3:Red-eye black dragon',2400,2000,7,'Dragon','Dark'),
                  4:monster_card_default('4:Ancient Lamp',1000,2000,5,'Spellcaster','Dark'),
                  5:monster_card_default('5:Armored Lizard',1500,1200,4,'Warrior','Light'),
                  6:monster_card_default('6:Armored Zombie',1500,0,3,'Warrior','Dark'),
                  7:monster_card_default('7:Axe Raider',1700,1150,4,'Warrior','Light'),
                  8:monster_card_default('8:Skull Dragon',3200,2500,9,'Dragon','Dark'),
                  9:monster_card_default('9:Baby Dragon',1200,700,3,'Dragon','Dark'),
                  10:monster_card_default('10:Barox',1380,1530,5,'Spellcaster','Light'),
                  11:monster_card_default('11:Barrel Dragon',2600,2200,7,'Dragon','Dark'),
                  12:monster_card_default('12:Basic Insect',500,700,2,'Warrior','Light'),
                  13:monster_card_default('13:Battle Ox',1700,1000,4,'Warrior','Dark'),
                  14:monster_card_default('14:Battle Steer',1800,1300,5,'Warrior','Light'),
                  15:monster_card_default('15:Battle Warrior',700,100,3,'Warrior','Light'),

                  }
order_in_Dualist_1_deck=[num for num in range(1,len(all_monster_card)+1)]
order_in_Dualist_2_deck=[num for num in range(1,len(all_monster_card)+1)]  


# Rock Paper Scissors of who start frist

def shuffle_list(mylist):
    shuffle(mylist)
    return mylist

def select_RPS():

    your_select=''

    while your_select not in ['rock','paper','scissors']:
        your_select=input('pick rock paper scissors')

    return your_select

def your_opernant_pick():
  ai_select=shuffle_list(['rock','paper','scissors'])
  ai_pick=ai_select[random.randint(0,2)]
  return ai_pick

def Rock_Paper_Scissors():
  result_of_Rock_Paper_Scissors=0
  while result_of_Rock_Paper_Scissors==0:
    your_chose=select_RPS()
    # your_chose='Scissors'
    ai_chose=your_opernant_pick()
    print(f'your pick {your_chose} and your opernant pick {ai_chose}')
    
    if your_chose==ai_chose:
      print("Draw")
      print('Again')
    elif your_chose=='paper' and ai_chose=='rock':
      print("YOU Win")
      result_of_Rock_Paper_Scissors+=1
      return 1
    elif your_chose=='rock' and ai_chose=='scissors':
      print("YOU Win")
      result_of_Rock_Paper_Scissors+=1
      return 1
    elif your_chose=='scissors' and ai_chose=='paper':
      print("YOU Win")
      result_of_Rock_Paper_Scissors+=1
      return 1
    else:
      print("YOU Lose")
      result_of_Rock_Paper_Scissors+=1
      return 2
# return number of palyer 1 or 2 who win
# game logic loop
# dualist_deck=[random.randint(1,40)]      
random.shuffle(order_in_Dualist_1_deck)
random.shuffle(order_in_Dualist_2_deck)
player1_card_in_hand=[]
player1_card_name_in_hand=[]
player1_card_location_used=[]
player1_number_card_in_hand=0
player2_card_in_hand=[]
player2_card_name_in_hand=[]
player2_card_location_used=[]
player2_number_card_in_hand=0

play_turn=0
# player1_monster_card_in_field=[]
# player2_monster_card_in_field=[]
player1_dualist_data = player_dualist('yugi',4000,order_in_Dualist_1_deck)
player2_dualist_data = player_dualist('kaiba',4000,order_in_Dualist_2_deck)

player1_lp=player1_dualist_data.dualist_lp
player2_lp=player2_dualist_data.dualist_lp
player1_dualist_name = player1_dualist_data.dualist_name
player2_dualist_name = player2_dualist_data.dualist_name
print(player1_dualist_data)
print('vs')
print(player2_dualist_data)

# Rock_Paper_Scissors loop
start_frist_play_dualist=Rock_Paper_Scissors() #frist play dualist
print(f'dualist {start_frist_play_dualist} is going frist ')
  
# while player1_lp
start_draw_card_untill_have_5_card_in_hand(player1_number_card_in_hand,order_in_Dualist_1_deck,player1_card_in_hand,player1_card_location_used) #fix logic 
start_draw_card_untill_have_5_card_in_hand(player2_number_card_in_hand,order_in_Dualist_2_deck,player2_card_in_hand,player2_card_location_used) #fix logic 
dualist_card_name_in_hand(player1_card_name_in_hand,player1_card_in_hand,all_monster_card)
dualist_card_name_in_hand(player2_card_name_in_hand,player2_card_in_hand,all_monster_card)
print(f'{player1_dualist_data.dualist_name} start with {player1_card_name_in_hand}') 
print(f'{player2_dualist_data.dualist_name} start with {player2_card_name_in_hand}') 

# print(player1_card_in_hand)
# draw_card(order_in_Dualist_1_deck,player1_card_in_hand,player1_card_location_used)
# print(order_in_Dualist_1_deck)
# print(player1_card_in_hand)
# print(player1_card_location_used)
# LP of dualist collection
# player_dualist_1_lp=player1_dualist_data.dualist_lp
# player_dualist_2_lp=player2_dualist_data.dualist_lp
# loop untill LP is 0 
# while player_dualist_1_lp >0 and player_dualist_2_lp>0:
# each player select number of card in hand 
#    if 
# damage calculation 
# each playr draw and loop again 
if start_frist_play_dualist==1:
  current_player_dualist_name = player1_dualist_name
  current_player_card_in_hand = player1_card_in_hand
  current_player_card_name_in_hand = player1_card_name_in_hand
  current_player_card_location_used = player1_card_location_used
  current_player_number_card_in_hand = player1_number_card_in_hand
  current_order_in_Dualist_deck = order_in_Dualist_1_deck
  current_player_lp = player1_lp
  current_player_field_card = []
  current_player_atk_dmg=0
  current_player_summon=0
  other_player_dualist_name = player2_dualist_name
  other_player_card_in_hand = player2_card_in_hand
  other_player_card_name_in_hand = player2_card_name_in_hand
  other_player_card_location_used = player2_card_location_used
  other_player_number_card_in_hand = player2_number_card_in_hand
  other_order_in_Dualist_deck = order_in_Dualist_2_deck
  other_player_lp=player2_lp
  other_player_field_card = []
  other_player_atk_dmg=0
  other_player_summon=0
else :
  current_player_dualist_name = player2_dualist_name
  current_player_card_in_hand = player2_card_in_hand
  current_player_card_name_in_hand = player2_card_name_in_hand
  current_player_card_location_used = player2_card_location_used
  current_player_number_card_in_hand = player2_number_card_in_hand
  current_order_in_Dualist_deck = order_in_Dualist_2_deck
  current_player_lp=player2_lp
  current_player_field_card = []
  current_player_atk_dmg=0
  current_player_summon=0
  other_player_dualist_name = player1_dualist_name
  other_player_card_in_hand = player1_card_in_hand
  other_player_card_name_in_hand = player1_card_name_in_hand
  other_player_card_location_used = player1_card_location_used
  other_player_number_card_in_hand = player1_number_card_in_hand
  other_order_in_Dualist_deck = order_in_Dualist_1_deck
  other_player_lp=player1_lp
  other_player_field_card = []
  other_player_atk_dmg=0
  other_player_summon=0

while current_player_lp > 0 and other_player_lp > 0 :


  print(f'{play_turn} turn ::Dualist {current_player_dualist_name} you have {current_player_lp} lp')
  print('---it my turn DRAW---')
  draw_card(current_order_in_Dualist_deck,current_player_card_in_hand,current_player_card_location_used)
  current_player_number_card_in_hand+=1
  current_player_card_name_in_hand=[]
  current_player_card_name_in_hand = dualist_card_name_in_hand(current_player_card_name_in_hand,current_player_card_in_hand,all_monster_card)
  print(current_player_card_name_in_hand)
  print('---main phase---')

  while current_player_summon not in current_player_card_in_hand:
    current_player_summon = int(input('select number to summon monster'))

  
  # print(current_player_card_in_hand)
  current_player_field_card.append(current_player_summon)
  current_player_atk_dmg = all_monster_card[current_player_summon].monster_atk
  current_player_card_in_hand.remove(current_player_summon)
  print(f'summon {all_monster_card[current_player_summon].monster_name} {all_monster_card[current_player_summon].monster_atk} atk ')
  # print(current_player_card_in_hand)
  print('---end phase---')
  play_turn+=1


  if play_turn%2 == 0:

    print('---start battle phase---')
    print(f'dualist {current_player_dualist_name} summoned {all_monster_card[current_player_summon].monster_name} {current_player_atk_dmg} atk')
    print(f'dualist {other_player_dualist_name} summoned {all_monster_card[other_player_summon].monster_name} {other_player_atk_dmg} atk')

    if current_player_atk_dmg > other_player_atk_dmg:
      other_player_lp = other_player_lp-(current_player_atk_dmg - other_player_atk_dmg)
      print(f'--- {other_player_dualist_name} take {current_player_atk_dmg - other_player_atk_dmg} dmg ---')
    elif current_player_atk_dmg < other_player_atk_dmg:
      current_player_lp = current_player_lp-(other_player_atk_dmg - current_player_atk_dmg)
      print(f'--- {current_player_dualist_name} take {other_player_atk_dmg - current_player_atk_dmg } dmg ---')
    else:
      print('both monster destroyed')
    print('---end of battle phase---')
    current_player_atk_dmg = 0
    other_player_atk_dmg = 0
  else:
    pass
  
  # print(f'---frist cur deck: {current_order_in_Dualist_deck} player {current_player_dualist_name} card in hand {current_player_card_in_hand}---')
  # print(f'---frist other deck: {other_order_in_Dualist_deck} player {other_player_dualist_name} card in hand {other_player_card_in_hand}---')
  
  # switf
  temp_name = current_player_dualist_name
  temp_card_in_hand = current_player_card_in_hand 
  temp_card_name_in_hand  = current_player_card_name_in_hand 
  temp_card_location_used = current_player_card_location_used 
  temp_number_card_in_hand  = current_player_number_card_in_hand 
  temp_order_in_Dualist_deck  = current_order_in_Dualist_deck 
  temp_player_lp = current_player_lp 
  temp_field_card = current_player_field_card 
  temp_atk_dmg = current_player_atk_dmg
  temp_summon=current_player_summon
  
  current_player_dualist_name = other_player_dualist_name
  current_player_card_in_hand = other_player_card_in_hand 
  current_player_card_name_in_hand = other_player_card_name_in_hand 
  current_player_card_location_used = other_player_card_location_used 
  current_player_number_card_in_hand = other_player_number_card_in_hand
  current_order_in_Dualist_deck = other_order_in_Dualist_deck 
  current_player_lp = other_player_lp
  current_player_field_card  = other_player_field_card 
  current_player_atk_dmg = other_player_atk_dmg
  current_player_summon = other_player_summon
  
  other_player_dualist_name = temp_name
  other_player_card_in_hand = temp_card_in_hand
  other_player_card_name_in_hand = temp_card_name_in_hand
  other_player_card_location_used = temp_card_location_used
  other_player_number_card_in_hand = temp_number_card_in_hand
  other_order_in_Dualist_deck = temp_order_in_Dualist_deck
  other_player_lp=temp_player_lp
  other_player_field_card = temp_field_card
  other_player_atk_dmg = temp_atk_dmg
  other_player_summon = temp_summon

  # print(f'---temp deck: {temp_order_in_Dualist_deck} player {temp_name} card in hand {temp_number_card_in_hand}---' )
  # print(f'---second cur deck: {current_order_in_Dualist_deck} player {current_player_dualist_name} card in hand {current_player_card_in_hand}---')
  # print(f'---second other deck: {other_order_in_Dualist_deck} player {other_player_dualist_name} card in hand {other_player_card_in_hand}---')

  if current_player_lp <= 0 or other_player_lp <= 0:
    if current_player_lp <= 0:
      print(f'the winer is {other_player_dualist_name} ')
    elif other_player_lp <= 0:
      print(f'the winer is {current_player_dualist_name} ')  
    else :
      print('draw')
    break
# Out:
#  DUALIST ==yugi====4000LP==
# vs
#  DUALIST ==kaiba====4000LP==
# your pick rock and your opernant pick rock
# Draw
# Again
# your pick rock and your opernant pick paper
# YOU Lose
# dualist 2 is going frist
# yugi start with ['13:Battle Ox', '9:Baby Dragon', '15:Battle Warrior']
# kaiba start with ['6:Armored Zombie', '2:Black magician', '9:Baby Dragon']
# 0 turn ::Dualist kaiba you have 4000 lp
# ---it my turn DRAW---
# ['6:Armored Zombie', '2:Black magician', '9:Baby Dragon', '14:Battle Steer']
# ---main phase---
# summon 6:Armored Zombie 1500 atk
# ---end phase---
# ---frist cur deck: [6, 2, 9, 14, 5, 15, 4, 10, 8, 7, 13, 1, 11, 12, 3] player kaiba card in hand [2, 9, 14]---
# ---frist other deck: [13, 9, 15, 2, 6, 14, 5, 3, 7, 1, 11, 4, 8, 12, 10] player yugi card in hand [13, 9, 15]---
# ---temp deck: [6, 2, 9, 14, 5, 15, 4, 10, 8, 7, 13, 1, 11, 12, 3] player kaiba card in hand 1---
# ...
